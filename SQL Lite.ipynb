# %%
import pandas as pd
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String, Float

# %%
# Load in File from resources
file_path = 'output/population.csv'

# Read and display with pandas
df = pd.read_csv(file_path)
df.head()
# Out:
#             County  Population
# 0  Anderson County       57735
# 1   Andrews County       18705
# 2  Angelina County       86715
# 3   Aransas County       23510
# 4    Archer County        8553

# %%
engine = create_engine("sqlite:///Resources/texas_counties.sqlite")

# %%
# # reflect an existing database into a new model
# Base = automap_base()
# # reflect the tables
# Base.prepare(engine, reflect=True)

# %%
# Create the County Class
# ----------------------------------
class County(Base):
    __tablename__ = 'counties'
    id = Column(Integer, primary_key=True)
    county = Column(String(255))
    population = Column(Integer)
    med_income = Column(Integer)
    unemploy_rate = Column(Float)
    crime_rate = Column(Float)

# %%
# Create Database Connection
conn = engine.connect()

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
Base.metadata.create_all(engine)

# Use this to clear out the db
# ----------------------------------
# Base.metadata.drop_all(engine)

# %%
# Create a Session Object to Connect to DB
session = Session(bind=engine)

# %%
df.to_sql('counties', con=engine, if_exists='replace',
           index_label='id')
engine.execute("SELECT * FROM counties").fetchall()
# Out:
# [(0, 'Anderson County', 57735),
#  (1, 'Andrews County', 18705),
#  (2, 'Angelina County', 86715),
#  (3, 'Aransas County', 23510),
#  (4, 'Archer County', 8553),
#  (5, 'Armstrong County', 1887),
#  (6, 'Atascosa County', 51153),
#  (7, 'Austin County', 30032),
#  (8, 'Bailey County', 7000),
#  (9, 'Bandera County', 23112),
#  (10, 'Bastrop County', 88723),
#  (11, 'Baylor County', 3509),
#  (12, 'Bee County', 32565),
#  (13, 'Bell County', 362924),
#  (14, 'Bexar County', 2003554),
#  (15, 'Blanco County', 11931),
#  (16, 'Borden County', 654),
#  (17, 'Bosque County', 18685),
#  (18, 'Bowie County', 93245),
#  (19, 'Brazoria County', 374264),
#  (20, 'Brazos County', 229211),
#  (21, 'Brewster County', 9203),
#  (22, 'Briscoe County', 1546),
#  (23, 'Brooks County', 7093),
#  (24, 'Brown County', 37864),
#  (25, 'Burleson County', 18443),
#  (26, 'Burnet County', 48155),
#  (27, 'Caldwell County', 43664),
#  (28, 'Calhoun County', 21290),
#  (29, 'Callahan County', 13943),
#  (30, 'Cameron County', 423163),
#  (31, 'Camp County', 13094),
#  (32, 'Carson County', 5926),
#  (33, 'Cass County', 30026),
#  (34, 'Castro County', 7530),
#  (35, 'Chambers County', 43837),
#  (36, 'Cherokee County', 52646),
#  (37, 'Childress County', 7306),
#  (38, 'Clay County', 10471),
#  (39, 'Cochran County', 2853),
#  (40, 'Coke County', 3387),
#  (41, 'Coleman County', 8175),
#  (42, 'Collin County', 1034730),
#  (43, 'Collingsworth County', 2920),
#  (44, 'Colorado County', 21493),
#  (45, 'Comal County', 156209),
#  (46, 'Comanche County', 13635),
#  (47, 'Concho County', 2726),
#  (48, 'Cooke County', 41257),
#  (49, 'Coryell County', 75951),
#  (50, 'Cottle County', 1398),
#  (51, 'Crane County', 4797),
#  (52, 'Crockett County', 3464),
#  (53, 'Crosby County', 5737),
#  (54, 'Culberson County', 2171),
#  (55, 'Dallam County', 7287),
#  (56, 'Dallas County', 2635516),
#  (57, 'Dawson County', 12728),
#  (58, 'DeWitt County', 20160),
#  (59, 'Deaf Smith County', 18546),
#  (60, 'Delta County', 5331),
#  (61, 'Denton County', 887207),
#  (62, 'Dickens County', 2211),
#  (63, 'Dimmit County', 10124),
#  (64, 'Donley County', 3278),
#  (65, 'Duval County', 11157),
#  (66, 'Eastland County', 18360),
#  (67, 'Ector County', 166223),
#  (68, 'Edwards County', 1932),
#  (69, 'El Paso County', 839238),
#  (70, 'Ellis County', 184826),
#  (71, 'Erath County', 42698),
#  (72, 'Falls County', 17297),
#  (73, 'Fannin County', 35514),
#  (74, 'Fayette County', 25346),
#  (75, 'Fisher County', 3830),
#  (76, 'Floyd County', 5712),
#  (77, 'Foard County', 1155),
#  (78, 'Fort Bend County', 811688),
#  (79, 'Franklin County', 10725),
#  (80, 'Freestone County', 19717),
#  (81, 'Frio County', 20306),
#  (82, 'Gaines County', 21492),
#  (83, 'Galveston County', 342139),
#  (84, 'Garza County', 6229),
#  (85, 'Gillespie County', 26988),
#  (86, 'Glasscock County', 1409),
#  (87, 'Goliad County', 7658),
#  (88, 'Gonzales County', 20837),
#  (89, 'Gray County', 21886),
#  (90, 'Grayson County', 136212),
#  (91, 'Gregg County', 123945),
#  (92, 'Grimes County', 28880),
#  (93, 'Guadalupe County', 166847),
#  (94, 'Hale County', 33406),
#  (95, 'Hall County', 2964),
#  (96, 'Hamilton County', 8461),
#  (97, 'Hansford County', 5399),
#  (98, 'Hardeman County', 3933),
#  (99, 'Hardin County', 57602),
#  (100, 'Harris County', 4713325),
#  (101, 'Harrison County', 66553),
#  (102, 'Hartley County', 5576),
#  (103, 'Haskell County', 5658),
#  (104, 'Hays County', 230191),
#  (105, 'Hemphill County', 3819),
#  (106, 'Henderson County', 82737),
#  (107, 'Hidalgo County', 868707),
#  (108, 'Hill County', 36649),
#  (109, 'Hockley County', 23021),
#  (110, 'Hood County', 61643),
#  (111, 'Hopkins County', 37084),
#  (112, 'Houston County', 22968),
#  (113, 'Howard County', 36664),
#  (114, 'Hudspeth County', 4886),
#  (115, 'Hunt County', 98594),
#  (116, 'Hutchinson County', 20938),
#  (117, 'Irion County', 1536),
#  (118, 'Jack County', 8935),
#  (119, 'Jackson County', 14760),
#  (120, 'Jasper County', 35529),
#  (121, 'Jeff Davis County', 2274),
#  (122, 'Jefferson County', 251565),
#  (123, 'Jim Hogg County', 5200),
#  (124, 'Jim Wells County', 40482),
#  (125, 'Johnson County', 175817),
#  (126, 'Jones County', 20083),
#  (127, 'Karnes County', 15601),
#  (128, 'Kaufman County', 136154),
#  (129, 'Kendall County', 47431),
#  (130, 'Kenedy County', 404),
#  (131, 'Kent County', 762),
#  (132, 'Kerr County', 52600),
#  (133, 'Kimble County', 4337),
#  (134, 'King County', 272),
#  (135, 'Kinney County', 3667),
#  (136, 'Kleberg County', 30680),
#  (137, 'Knox County', 3664),
#  (138, 'La Salle County', 7520),
#  (139, 'Lamar County', 49859),
#  (140, 'Lamb County', 12893),
#  (141, 'Lampasas County', 21428),
#  (142, 'Lavaca County', 20154),
#  (143, 'Lee County', 17239),
#  (144, 'Leon County', 17404),
#  (145, 'Liberty County', 88219),
#  (146, 'Limestone County', 23437),
#  (147, 'Lipscomb County', 3233),
#  (148, 'Live Oak County', 12207),
#  (149, 'Llano County', 21795),
#  (150, 'Loving County', 169),
#  (151, 'Lubbock County', 310569),
#  (152, 'Lynn County', 5951),
#  (153, 'Madison County', 14284),
#  (154, 'Marion County', 9854),
#  (155, 'Martin County', 5771),
#  (156, 'Mason County', 4274),
#  (157, 'Matagorda County', 36643),
#  (158, 'Maverick County', 58722),
#  (159, 'McCulloch County', 7984),
#  (160, 'McLennan County', 256623),
#  (161, 'McMullen County', 743),
#  (162, 'Medina County', 51584),
#  (163, 'Menard County', 2138),
#  (164, 'Midland County', 176832),
#  (165, 'Milam County', 24823),
#  (166, 'Mills County', 4873),
#  (167, 'Mitchell County', 8545),
#  (168, 'Montague County', 19818),
#  (169, 'Montgomery County', 607391),
#  (170, 'Moore County', 20940),
#  (171, 'Morris County', 12388),
#  (172, 'Motley County', 1200),
#  (173, 'Nacogdoches County', 65204),
#  (174, 'Navarro County', 50113),
#  (175, 'Newton County', 13595),
#  (176, 'Nolan County', 14714),
#  (177, 'Nueces County', 362294),
#  (178, 'Ochiltree County', 9836),
#  (179, 'Oldham County', 2112),
#  (180, 'Orange County', 83396),
#  (181, 'Palo Pinto County', 29189),
#  (182, 'Panola County', 23194),
#  (183, 'Parker County', 142878),
#  (184, 'Parmer County', 9605),
#  (185, 'Pecos County', 15823),
#  (186, 'Polk County', 51353),
#  (187, 'Potter County', 117415),
#  (188, 'Presidio County', 6704),
#  (189, 'Rains County', 12514),
#  (190, 'Randall County', 137713),
#  (191, 'Reagan County', 3849),
#  (192, 'Real County', 3452),
#  (193, 'Red River County', 12023),
#  (194, 'Reeves County', 15976),
#  (195, 'Refugio County', 6948),
#  (196, 'Roberts County', 854),
#  (197, 'Robertson County', 17074),
#  (198, 'Rockwall County', 104915),
#  (199, 'Runnels County', 10264),
#  (200, 'Rusk County', 54406),
#  (201, 'Sabine County', 10542),
#  (202, 'San Augustine County', 8237),
#  (203, 'San Jacinto County', 28859),
#  (204, 'San Patricio County', 66730),
#  (205, 'San Saba County', 6055),
#  (206, 'Schleicher County', 2793),
#  (207, 'Scurry County', 16703),
#  (208, 'Shackelford County', 3265),
#  (209, 'Shelby County', 25274),
#  (210, 'Sherman County', 3022),
#  (211, 'Smith County', 232751),
#  (212, 'Somervell County', 9128),
#  (213, 'Starr County', 64633),
#  (214, 'Stephens County', 9366),
#  (215, 'Sterling County', 1291),
#  (216, 'Stonewall County', 1350),
#  (217, 'Sutton County', 3776),
#  (218, 'Swisher County', 7397),
#  (219, 'Tarrant County', 2102515),
#  (220, 'Taylor County', 138034),
#  (221, 'Terrell County', 776),
#  (222, 'Terry County', 12337),
#  (223, 'Throckmorton County', 1501),
#  (224, 'Titus County', 32750),
#  (225, 'Tom Green County', 119200),
#  (226, 'Travis County', 1273954),
#  (227, 'Trinity County', 14651),
#  (228, 'Tyler County', 21672),
#  (229, 'Upshur County', 41753),
#  (230, 'Upton County', 3657),
#  (231, 'Uvalde County', 26741),
#  (232, 'Val Verde County', 49025),
#  (233, 'Van Zandt County', 56590),
#  (234, 'Victoria County', 92084),
#  (235, 'Walker County', 72971),
#  (236, 'Waller County', 55246),
#  (237, 'Ward County', 11998),
#  (238, 'Washington County', 35882),
#  (239, 'Webb County', 276652),
#  (240, 'Wharton County', 41556),
#  (241, 'Wheeler County', 5056),
#  (242, 'Wichita County', 132230),
#  (243, 'Wilbarger County', 12769),
#  (244, 'Willacy County', 21358),
#  (245, 'Williamson County', 590551),
#  (246, 'Wilson County', 51070),
#  (247, 'Winkler County', 8010),
#  (248, 'Wise County', 69984),
#  (249, 'Wood County', 45539),
#  (250, 'Yoakum County', 8713),
#  (251, 'Young County', 18010),
#  (252, 'Zapata County', 14179),
#  (253, 'Zavala County', 11840)]

# %%
# Query the Tables
# ----------------------------------
# Perform a simple query of the database
data = engine.execute("SELECT * FROM counties")

for record in data:
    print(record)
# Out:
# (0, 'Anderson County', 57735)
# (1, 'Andrews County', 18705)
# (2, 'Angelina County', 86715)
# (3, 'Aransas County', 23510)
# (4, 'Archer County', 8553)
# (5, 'Armstrong County', 1887)
# (6, 'Atascosa County', 51153)
# (7, 'Austin County', 30032)
# (8, 'Bailey County', 7000)
# (9, 'Bandera County', 23112)
# (10, 'Bastrop County', 88723)
# (11, 'Baylor County', 3509)
# (12, 'Bee County', 32565)
# (13, 'Bell County', 362924)
# (14, 'Bexar County', 2003554)
# (15, 'Blanco County', 11931)
# (16, 'Borden County', 654)
# (17, 'Bosque County', 18685)
# (18, 'Bowie County', 93245)
# (19, 'Brazoria County', 374264)
# (20, 'Brazos County', 229211)
# (21, 'Brewster County', 9203)
# (22, 'Briscoe County', 1546)
# (23, 'Brooks County', 7093)
# (24, 'Brown County', 37864)
# (25, 'Burleson County', 18443)
# (26, 'Burnet County', 48155)
# (27, 'Caldwell County', 43664)
# (28, 'Calhoun County', 21290)
# (29, 'Callahan County', 13943)
# (30, 'Cameron County', 423163)
# (31, 'Camp County', 13094)
# (32, 'Carson County', 5926)
# (33, 'Cass County', 30026)
# (34, 'Castro County', 7530)
# (35, 'Chambers County', 43837)
# (36, 'Cherokee County', 52646)
# (37, 'Childress County', 7306)
# (38, 'Clay County', 10471)
# (39, 'Cochran County', 2853)
# (40, 'Coke County', 3387)
# (41, 'Coleman County', 8175)
# (42, 'Collin County', 1034730)
# (43, 'Collingsworth County', 2920)
# (44, 'Colorado County', 21493)
# (45, 'Comal County', 156209)
# (46, 'Comanche County', 13635)
# (47, 'Concho County', 2726)
# (48, 'Cooke County', 41257)
# (49, 'Coryell County', 75951)
# (50, 'Cottle County', 1398)
# (51, 'Crane County', 4797)
# (52, 'Crockett County', 3464)
# (53, 'Crosby County', 5737)
# (54, 'Culberson County', 2171)
# (55, 'Dallam County', 7287)
# (56, 'Dallas County', 2635516)
# (57, 'Dawson County', 12728)
# (58, 'DeWitt County', 20160)
# (59, 'Deaf Smith County', 18546)
# (60, 'Delta County', 5331)
# (61, 'Denton County', 887207)
# (62, 'Dickens County', 2211)
# (63, 'Dimmit County', 10124)
# (64, 'Donley County', 3278)
# (65, 'Duval County', 11157)
# (66, 'Eastland County', 18360)
# (67, 'Ector County', 166223)
# (68, 'Edwards County', 1932)
# (69, 'El Paso County', 839238)
# (70, 'Ellis County', 184826)
# (71, 'Erath County', 42698)
# (72, 'Falls County', 17297)
# (73, 'Fannin County', 35514)
# (74, 'Fayette County', 25346)
# (75, 'Fisher County', 3830)
# (76, 'Floyd County', 5712)
# (77, 'Foard County', 1155)
# (78, 'Fort Bend County', 811688)
# (79, 'Franklin County', 10725)
# (80, 'Freestone County', 19717)
# (81, 'Frio County', 20306)
# (82, 'Gaines County', 21492)
# (83, 'Galveston County', 342139)
# (84, 'Garza County', 6229)
# (85, 'Gillespie County', 26988)
# (86, 'Glasscock County', 1409)
# (87, 'Goliad County', 7658)
# (88, 'Gonzales County', 20837)
# (89, 'Gray County', 21886)
# (90, 'Grayson County', 136212)
# (91, 'Gregg County', 123945)
# (92, 'Grimes County', 28880)
# (93, 'Guadalupe County', 166847)
# (94, 'Hale County', 33406)
# (95, 'Hall County', 2964)
# (96, 'Hamilton County', 8461)
# (97, 'Hansford County', 5399)
# (98, 'Hardeman County', 3933)
# (99, 'Hardin County', 57602)
# (100, 'Harris County', 4713325)
# (101, 'Harrison County', 66553)
# (102, 'Hartley County', 5576)
# (103, 'Haskell County', 5658)
# (104, 'Hays County', 230191)
# (105, 'Hemphill County', 3819)
# (106, 'Henderson County', 82737)
# (107, 'Hidalgo County', 868707)
# (108, 'Hill County', 36649)
# (109, 'Hockley County', 23021)
# (110, 'Hood County', 61643)
# (111, 'Hopkins County', 37084)
# (112, 'Houston County', 22968)
# (113, 'Howard County', 36664)
# (114, 'Hudspeth County', 4886)
# (115, 'Hunt County', 98594)
# (116, 'Hutchinson County', 20938)
# (117, 'Irion County', 1536)
# (118, 'Jack County', 8935)
# (119, 'Jackson County', 14760)
# (120, 'Jasper County', 35529)
# (121, 'Jeff Davis County', 2274)
# (122, 'Jefferson County', 251565)
# (123, 'Jim Hogg County', 5200)
# (124, 'Jim Wells County', 40482)
# (125, 'Johnson County', 175817)
# (126, 'Jones County', 20083)
# (127, 'Karnes County', 15601)
# (128, 'Kaufman County', 136154)
# (129, 'Kendall County', 47431)
# (130, 'Kenedy County', 404)
# (131, 'Kent County', 762)
# (132, 'Kerr County', 52600)
# (133, 'Kimble County', 4337)
# (134, 'King County', 272)
# (135, 'Kinney County', 3667)
# (136, 'Kleberg County', 30680)
# (137, 'Knox County', 3664)
# (138, 'La Salle County', 7520)
# (139, 'Lamar County', 49859)
# (140, 'Lamb County', 12893)
# (141, 'Lampasas County', 21428)
# (142, 'Lavaca County', 20154)
# (143, 'Lee County', 17239)
# (144, 'Leon County', 17404)
# (145, 'Liberty County', 88219)
# (146, 'Limestone County', 23437)
# (147, 'Lipscomb County', 3233)
# (148, 'Live Oak County', 12207)
# (149, 'Llano County', 21795)
# (150, 'Loving County', 169)
# (151, 'Lubbock County', 310569)
# (152, 'Lynn County', 5951)
# (153, 'Madison County', 14284)
# (154, 'Marion County', 9854)
# (155, 'Martin County', 5771)
# (156, 'Mason County', 4274)
# (157, 'Matagorda County', 36643)
# (158, 'Maverick County', 58722)
# (159, 'McCulloch County', 7984)
# (160, 'McLennan County', 256623)
# (161, 'McMullen County', 743)
# (162, 'Medina County', 51584)
# (163, 'Menard County', 2138)
# (164, 'Midland County', 176832)
# (165, 'Milam County', 24823)
# (166, 'Mills County', 4873)
# (167, 'Mitchell County', 8545)
# (168, 'Montague County', 19818)
# (169, 'Montgomery County', 607391)
# (170, 'Moore County', 20940)
# (171, 'Morris County', 12388)
# (172, 'Motley County', 1200)
# (173, 'Nacogdoches County', 65204)
# (174, 'Navarro County', 50113)
# (175, 'Newton County', 13595)
# (176, 'Nolan County', 14714)
# (177, 'Nueces County', 362294)
# (178, 'Ochiltree County', 9836)
# (179, 'Oldham County', 2112)
# (180, 'Orange County', 83396)
# (181, 'Palo Pinto County', 29189)
# (182, 'Panola County', 23194)
# (183, 'Parker County', 142878)
# (184, 'Parmer County', 9605)
# (185, 'Pecos County', 15823)
# (186, 'Polk County', 51353)
# (187, 'Potter County', 117415)
# (188, 'Presidio County', 6704)
# (189, 'Rains County', 12514)
# (190, 'Randall County', 137713)
# (191, 'Reagan County', 3849)
# (192, 'Real County', 3452)
# (193, 'Red River County', 12023)
# (194, 'Reeves County', 15976)
# (195, 'Refugio County', 6948)
# (196, 'Roberts County', 854)
# (197, 'Robertson County', 17074)
# (198, 'Rockwall County', 104915)
# (199, 'Runnels County', 10264)
# (200, 'Rusk County', 54406)
# (201, 'Sabine County', 10542)
# (202, 'San Augustine County', 8237)
# (203, 'San Jacinto County', 28859)
# (204, 'San Patricio County', 66730)
# (205, 'San Saba County', 6055)
# (206, 'Schleicher County', 2793)
# (207, 'Scurry County', 16703)
# (208, 'Shackelford County', 3265)
# (209, 'Shelby County', 25274)
# (210, 'Sherman County', 3022)
# (211, 'Smith County', 232751)
# (212, 'Somervell County', 9128)
# (213, 'Starr County', 64633)
# (214, 'Stephens County', 9366)
# (215, 'Sterling County', 1291)
# (216, 'Stonewall County', 1350)
# (217, 'Sutton County', 3776)
# (218, 'Swisher County', 7397)
# (219, 'Tarrant County', 2102515)
# (220, 'Taylor County', 138034)
# (221, 'Terrell County', 776)
# (222, 'Terry County', 12337)
# (223, 'Throckmorton County', 1501)
# (224, 'Titus County', 32750)
# (225, 'Tom Green County', 119200)
# (226, 'Travis County', 1273954)
# (227, 'Trinity County', 14651)
# (228, 'Tyler County', 21672)
# (229, 'Upshur County', 41753)
# (230, 'Upton County', 3657)
# (231, 'Uvalde County', 26741)
# (232, 'Val Verde County', 49025)
# (233, 'Van Zandt County', 56590)
# (234, 'Victoria County', 92084)
# (235, 'Walker County', 72971)
# (236, 'Waller County', 55246)
# (237, 'Ward County', 11998)
# (238, 'Washington County', 35882)
# (239, 'Webb County', 276652)
# (240, 'Wharton County', 41556)
# (241, 'Wheeler County', 5056)
# (242, 'Wichita County', 132230)
# (243, 'Wilbarger County', 12769)
# (244, 'Willacy County', 21358)
# (245, 'Williamson County', 590551)
# (246, 'Wilson County', 51070)
# (247, 'Winkler County', 8010)
# (248, 'Wise County', 69984)
# (249, 'Wood County', 45539)
# (250, 'Yoakum County', 8713)
# (251, 'Young County', 18010)
# (252, 'Zapata County', 14179)
# (253, 'Zavala County', 11840)
