# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests

# %%
## Set up splinter
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Bring in the website to be scraped
url = 'https://www.texas-demographics.com/counties_by_population'
browser.visit(url)

# %%
table = pd.read_html(url)
population_df = table[0]

# %%
population_df
# Out:
#                                                   Rank  \
# 0                                                    1
# 1                                                    2
# 2                                                    3
# 3                                                    4
# 4                                                    5
# ..                                                 ...
# 250                                                251
# 251                                                252
# 252                                                253
# 253                                                254
# 254  United States Census Bureau. B01001 SEX BY AGE...
#
#                                                 County  \
# 0                                        Harris County
# 1                                        Dallas County
# 2                                       Tarrant County
# 3                                         Bexar County
# 4                                        Travis County
# ..                                                 ...
# 250                                      Borden County
# 251                                      Kenedy County
# 252                                        King County
# 253                                      Loving County
# 254  United States Census Bureau. B01001 SEX BY AGE...
#
#                                             Population
# 0                                              4713325
# 1                                              2635516
# 2                                              2102515
# 3                                              2003554
# 4                                              1273954
# ..                                                 ...
# 250                                                654
# 251                                                404
# 252                                                272
# 253                                                169
# 254  United States Census Bureau. B01001 SEX BY AGE...
#
# [255 rows x 3 columns]

# %%
population_df.set_index("Rank", inplace=True)
population_df
# Out:
#                                                                                                County  \
# Rank
# 1                                                                                       Harris County
# 2                                                                                       Dallas County
# 3                                                                                      Tarrant County
# 4                                                                                        Bexar County
# 5                                                                                       Travis County
# ...                                                                                               ...
# 251                                                                                     Borden County
# 252                                                                                     Kenedy County
# 253                                                                                       King County
# 254                                                                                     Loving County
# United States Census Bureau. B01001 SEX BY AGE,...  United States Census Bureau. B01001 SEX BY AGE...
#
#                                                                                            Population
# Rank
# 1                                                                                             4713325
# 2                                                                                             2635516
# 3                                                                                             2102515
# 4                                                                                             2003554
# 5                                                                                             1273954
# ...                                                                                               ...
# 251                                                                                               654
# 252                                                                                               404
# 253                                                                                               272
# 254                                                                                               169
# United States Census Bureau. B01001 SEX BY AGE,...  United States Census Bureau. B01001 SEX BY AGE...
#
# [255 rows x 2 columns]

# %%
clean_pop_df = population_df.iloc[0:254]
clean_pop_df
# Out:
#                County Population
# Rank
# 1       Harris County    4713325
# 2       Dallas County    2635516
# 3      Tarrant County    2102515
# 4        Bexar County    2003554
# 5       Travis County    1273954
# ...               ...        ...
# 250   McMullen County        743
# 251     Borden County        654
# 252     Kenedy County        404
# 253       King County        272
# 254     Loving County        169
#
# [254 rows x 2 columns]

# %%
clean_pop_df.to_csv("output/population.csv", index = False)
